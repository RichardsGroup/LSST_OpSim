# %% [markdown]
# ### Run logTgapsMetric on Multiple FBS_1.4 OpSims

# %% [markdown]
# Notebook uses Multiple_Opsims.ipynb from https://github.com/RichardsGroup/LSST_OpSim/tree/master/Scripts_NBs
# as the template.
#
# Here we analyze all 75 FBS 1.4 opSims in light of the distribution of time separations, which is already an existing metric [https://sims-maf.lsst.io/_modules/lsst/sims/maf/metrics/tgaps.html#TgapsMetric](https://sims-maf.lsst.io/_modules/lsst/sims/maf/metrics/tgaps.html#TgapsMetric).  However, in this case, we look at the distribution in *log* space.  Specifically from 30s to 10 years (converted to days).  The reasoning being that characterization of AGN structure functions (or PSDs) may benefit from a relatively uniform distribution in $log \Delta t$ space.  Rolling cadences may benefit AGNs (enabling more short time-separation observations), but extreme rolling cadences would be very bad (leaving few or no long time-separation observations).  For further discussion see the [relevant whitepaper](https://docushare.lsstcorp.org/docushare/dsweb/Get/Document-30572/richards_agn_rolling_wfd.pdf).

# %%
# import matplotlib to show plots inline.
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import glob
import os

# %% [markdown]
# Import the sims_maf modules needed.

# %%
# import lsst.sim.maf moduels modules
import lsst.sims.maf.db as db
import lsst.sims.maf.metrics as metrics
import lsst.sims.maf.slicers as slicers
import lsst.sims.maf.stackers as stackers
import lsst.sims.maf.plots as plots
import lsst.sims.maf.metricBundles as metricBundles

# %%
# import convenience functions
from opsimUtils import *

# %% [markdown]
# #### 1. Build connections to the OpSims databases
# The first step is to initiate opsim database objects and result database objects for the opsim databases that you want to run metrics on. Two paths are needed here:
# 1. `dbDir`: The path to the OpSim database directory
# 2. `outDir`: The path to the directory where you want to save the metric metadata.
#
# By providing these two paths, the function `connect_dbs()` will initiate connections and store the metadata to the designated directory.

# %% [markdown]
# N.B.  The `outDir` here is hardcoded for GTR's path.

# %%
# Two path are needed
dbDir = '/home/idies/workspace/lsst_cadence/FBS_1.4/' #global location of opSims
#dbDir = '/home/idies/workspace/LSST Cadence Simulations/FBS_1.4/' #global location of opSims
outDir = '/home/idies/workspace/Storage/gtr/persistent/MAFOutput/' #Output for GTR metrics

if not os.path.exists(os.path.abspath(outDir)):
    os.mkdir(os.path.abspath(outDir))

# %%
# two dictionary are returned by the following function, 
# One (opSimDbs) is a dictionary storing all database objects
# Another (resultDbs) is a dictionary consist of the objects directing MAF where to save metric metadata
# Both dictionaries are indexed by OpSim run names
opSimDbs, resultDbs = connect_dbs(dbDir, outDir)

# Collect Run names to a list
dbRuns = list(opSimDbs.keys())

# %% [markdown]
# You can use `help` to get more information about the provided convenience functions, e.g., `connect_dbs()`

# %%
help(connect_dbs)
# Out:
# Help on function connect_dbs in module opsimUtils:
#
# connect_dbs(dbDir, outDir)
#     Initiate database objects to all opSim databases in the provided directory.
#     Returns a dictionary consisting all database connections and a dictionary holding
#     the resultsDb objects.
#
#     Args:
#         dbDir(str): The path to the dabase directory.
#         outDir(str): The path to the result database directory.
#
#     Returns:
#         opSimDbs(dict): A dictionary containing the OpsimDatabase objects for opsim databases in the provided directory, keys are the run names.
#         resultDbs(str): A dictionary containing the ResultsDb objects for opsim databases in the provided directory, keys are the run names.

# %% [markdown]
# You can also check what OpSims are available in the directory

# %%
show_opsims(dbDir)
# Out:
# ['wfd_depth_scale0.85_noddf_v1.4_10yrs.db',
#  'twilight_neo_mod2_v1.4_10yrs.db',
#  'weather_0.3_v1.4_10yrs.db',
#  'pair_strategy_4_v1.4_10yrs.db',
#  'short_exp_2ns_1expt_v1.4_10yrs.db',
#  'sat_dodge_v1.4_10yrs.db',
#  'footprint_big_sky_dustv1.4_10yrs.db',
#  'roll_mod2_dust_sdf_0.20_v1.4_10yrs.db',
#  'pair_strategy_1_v1.4_10yrs.db',
#  'alt_roll_mod2_dust_sdf_0.20_v1.4_10yrs.db',
#  'wfd_depth_scale0.99_v1.4_10yrs.db',
#  'dcr_nham5_v1.4_10yrs.db',
#  'rolling_mod6_sdf_0.20_v1.4_10yrs.db',
#  'spiders_v1.4_10yrs.db',
#  'agnddf_v1.4_10yrs.db',
#  'twi_filters_5_v1.4_10yrs.db',
#  'baseline_2snapsv1.4_10yrs.db',
#  'wfd_depth_scale0.70_noddf_v1.4_10yrs.db',
#  'baseline_v1.4_10yrs.db',
#  'short_exp_5ns_1expt_v1.4_10yrs.db',
#  'bulges_i_heavy_v1.4_10yrs.db',
#  'rolling_mod3_sdf_0.10_v1.4_10yrs.db',
#  'bulges_cadence_bs_v1.4_10yrs.db',
#  'dcr_nham2_v1.4_10yrs.db',
#  'wfd_depth_scale0.95_noddf_v1.4_10yrs.db',
#  'twi_filters_2_v1.4_10yrs.db',
#  'bulges_cadence_i_heavy_v1.4_10yrs.db',
#  'wfd_depth_scale0.65_v1.4_10yrs.db',
#  'footprint_big_skyv1.4_10yrs.db',
#  'descddf_v1.4_10yrs.db',
#  'bulges_cadence_bulge_wfd_v1.4_10yrs.db',
#  'wfd_depth_scale0.80_v1.4_10yrs.db',
#  'pair_strategy_3_v1.4_10yrs.db',
#  'rolling_mod2_sdf_0.10_v1.4_10yrs.db',
#  'footprint_no_gp_northv1.4_10yrs.db',
#  'footprint_bluer_footprintv1.4_10yrs.db',
#  'wfd_depth_scale0.85_v1.4_10yrs.db',
#  'twilight_neo_mod1_v1.4_10yrs.db',
#  'wfd_depth_scale0.90_v1.4_10yrs.db',
#  'twilight_neo_mod4_v1.4_10yrs.db',
#  'footprint_add_mag_cloudsv1.4_10yrs.db',
#  'wfd_depth_scale0.95_v1.4_10yrs.db',
#  'rolling_mod6_sdf_0.10_v1.4_10yrs.db',
#  'pair_strategy_2_v1.4_10yrs.db',
#  'wfd_depth_scale0.70_v1.4_10yrs.db',
#  'twi_filters_3_v1.4_10yrs.db',
#  'wfd_depth_scale0.90_noddf_v1.4_10yrs.db',
#  'var_expt_v1.4_10yrs.db',
#  'footprint_gp_smoothv1.4_10yrs.db',
#  'euclidddf_v1.4_10yrs.db',
#  'wfd_depth_scale0.75_noddf_v1.4_10yrs.db',
#  'short_exp_2ns_5expt_v1.4_10yrs.db',
#  'footprint_big_sky_nouiyv1.4_10yrs.db',
#  'wfd_depth_scale0.75_v1.4_10yrs.db',
#  'wfd_depth_scale0.99_noddf_v1.4_10yrs.db',
#  'dcr_nham3_v1.4_10yrs.db',
#  'rolling_mod2_sdf_0.20_v1.4_10yrs.db',
#  'bulges_bs_v1.4_10yrs.db',
#  'twi_filters_4_v1.4_10yrs.db',
#  'dcr_nham1_v1.4_10yrs.db',
#  'footprint_newAv1.4_10yrs.db',
#  'footprint_standard_goalsv1.4_10yrs.db',
#  'bulges_bulge_wfd_v1.4_10yrs.db',
#  'twi_filters_1_v1.4_10yrs.db',
#  'weather_1.2_v1.4_10yrs.db',
#  'footprint_newBv1.4_10yrs.db',
#  'dcr_nham4_v1.4_10yrs.db',
#  'weather_0.7_v1.4_10yrs.db',
#  'short_exp_5ns_5expt_v1.4_10yrs.db',
#  'wfd_depth_scale0.65_noddf_v1.4_10yrs.db',
#  'footprint_stuck_rollingv1.4_10yrs.db',
#  'wfd_depth_scale0.80_noddf_v1.4_10yrs.db',
#  'pair_strategy_0_v1.4_10yrs.db',
#  'twilight_neo_mod3_v1.4_10yrs.db',
#  'rolling_mod3_sdf_0.20_v1.4_10yrs.db',
#  'weather_1.2_ndt_v1.4_10yrs.db']

# %% [markdown]
# #### 2. Define logTgapsMetric
#
# This is derived from https://sims-maf.lsst.io/lsst.sims.maf.metrics.html#module-lsst.sims.maf.metrics.tgaps
#
# This metric is almost exactly the same, but hard codes the use of *all* pairs and bins that are log distributed (from 30s to 10 yrs).

# %%
#From 30s to 10 years (~3e8s), converted to days, 99 bins
bins=np.logspace(np.log10(30.0/60./60./24.),np.log10(3e8/60./60./24.),99)

# %% [markdown]
# This next cell defines the metric.  Note that all but one line below is meta data or bookkeeping and the one line that is the actual metric is a bit obtuse.  It might be useful to comment it in more detail (and perhaps to break it down into multiple lines that are easier to read, even if those lines are just commented out).

# %%
#from .baseMetric import BaseMetric
from lsst.sims.maf.metrics import BaseMetric

#__all__ = ['TgapsMetric', 'NightgapsMetric', 'NVisitsPerNightMetric']

class logTgapsMetric(BaseMetric):
    """Histogram the log of the times of the gaps between observations.

    equivalent to TgapsMetric, but with 
    allGaps=True 
    and 
    bins = np.logspace(-3.46,3.54,99) (30s to 10yrs, converted to days)
    
    That yields log distribution of time gaps for all pairs.

    Parameters
    ----------
    timesCol : str, opt
        The column name for the exposure times.  Values assumed to be in days.
        Default observationStartMJD.
    allGaps : bool, opt
        Histogram the gaps between all observations (True) or just successive observations (False)?
        Default is True. If all gaps are used, this metric can become significantly slower.
    bins : np.ndarray, opt
        The bins to use for the histogram of time gaps (in days, or same units as timesCol).
        Default values are log bins from 30s to 10 years.

    Returns a histogram at each slice point; these histograms can be combined and plotted using the
    'SummaryHistogram plotter'.
     """

    def __init__(self, timesCol='observationStartMJD', allGaps=True, \
                 bins=np.logspace(np.log10(30.0/60./60./24.),np.log10(3e8/60./60./24.),99), \
                 units='days', **kwargs):
        # Pass the same bins to the plotter.
        self.bins = bins
        self.timesCol = timesCol
        super(logTgapsMetric, self).__init__(col=[self.timesCol], metricDtype='object', units=units, **kwargs)
        self.allGaps = allGaps

    def run(self, dataSlice, slicePoint=None):
        if dataSlice.size < 2:
            return self.badval
        times = np.sort(dataSlice[self.timesCol])
        if self.allGaps:
            allDiffs = []
            for i in np.arange(1,times.size,1):
                allDiffs.append((times-np.roll(times,i))[i:])
            dts = np.concatenate(allDiffs)
        else:
            dts = np.diff(times)
        #print(dts,np.log10(dts))
        result, bins = np.histogram(dts, self.bins)
        #print(result)
        return result

# %% [markdown]
# #### 3. Declare metric to run on all the opSims.
#
# Currently just looking at the logTgapsMetric in the r-band, but there is no reason not to do other bands (or to look at the DDFs).

# %%
# metric = analysis of histogram of log time separation for observations
metric1 = logTgapsMetric()

# slicer = a grouping or subdivision of visits for the simulated survey
# based on their position on the sky (using a Healpix grid)
slicer1 = slicers.HealpixSlicer(nside=64)

# constraint = the sql query (or 'select') that selects all visits in r band
constraint1 = 'filter = "r"'
constraint1 += ' and note not like "DD%"' # added so the sky plot won't saturate (remove DDFs)
# Out:
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes

# %%
# MetricBundle = combination of the metric, slicer, and sqlconstraint
logTgapsBundle = metricBundles.MetricBundle(metric1, slicer1, constraint1)

# %%
bundleDict = {'logTgaps': logTgapsBundle}

# %% [markdown]
# #### 4. Loop over all OpSims in dbDir and run MAF
# While constructing a metricBundleGroup from a dictionary (the cell below), you will need to provide the path to a directory (`metricDataPath` in the cell below) where you would like to store the metric data (this is **DIFFERENT** than path to the metric data, `outDir`). To construct metricbundles for plotting and further analysis, this path will be needed.

# %%
metricDataPath = '/home/idies/workspace/Storage/gtr/persistent/MAFOutput/MetricData/'
#for run in dbRuns[0:3]:  #To just run the first few.
for i,run in enumerate(dbRuns):
    # must set run name for each opSim to store metric data into
    # separate files
    print(i,run) #Comment out if just running the first few
    logTgapsBundle.setRunName(run)
    metricGroup = metricBundles.MetricBundleGroup(bundleDict,\
                    opSimDbs[run], metricDataPath, resultDbs[run])
    metricGroup.runAll()
# Out:
# 0 wfd_depth_scale0.85_noddf_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 481548 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 1 twilight_neo_mod2_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 536416 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 2 weather_0.3_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 435973 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 3 pair_strategy_4_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 435457 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 4 short_exp_2ns_1expt_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 493483 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 5 sat_dodge_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 436072 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 6 footprint_big_sky_dustv1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 429874 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 7 roll_mod2_dust_sdf_0.20_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 430994 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 8 pair_strategy_1_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 433644 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 9 alt_roll_mod2_dust_sdf_0.20_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 434147 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 10 wfd_depth_scale0.99_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 432388 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 11 dcr_nham5_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 425813 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 12 rolling_mod6_sdf_0.20_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 432542 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 13 spiders_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 435247 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 14 agnddf_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 454176 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 15 twi_filters_5_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 434337 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 16 baseline_2snapsv1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 400240 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 17 wfd_depth_scale0.70_noddf_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 489777 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 18 baseline_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 433755 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 19 short_exp_5ns_1expt_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 563779 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 20 bulges_i_heavy_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 429130 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 21 rolling_mod3_sdf_0.10_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 434224 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 22 bulges_cadence_bs_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 432063 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 23 dcr_nham2_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 429561 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 24 wfd_depth_scale0.95_noddf_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 476663 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 25 twi_filters_2_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 435233 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 26 bulges_cadence_i_heavy_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 429311 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 27 wfd_depth_scale0.65_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 444401 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 28 footprint_big_skyv1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 442530 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 29 descddf_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 450376 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 30 bulges_cadence_bulge_wfd_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 431502 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 31 wfd_depth_scale0.80_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 438577 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 32 pair_strategy_3_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 440551 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 33 rolling_mod2_sdf_0.10_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 432910 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 34 footprint_no_gp_northv1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 436099 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 35 footprint_bluer_footprintv1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 446050 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 36 wfd_depth_scale0.85_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 436127 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 37 twilight_neo_mod1_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 649475 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 38 wfd_depth_scale0.90_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 433791 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 39 twilight_neo_mod4_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 483199 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 40 footprint_add_mag_cloudsv1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 436783 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 41 wfd_depth_scale0.95_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 431805 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 42 rolling_mod6_sdf_0.10_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 434023 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 43 pair_strategy_2_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 439835 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 44 wfd_depth_scale0.70_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 442787 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 45 twi_filters_3_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 422479 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 46 wfd_depth_scale0.90_noddf_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 479047 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 47 var_expt_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 408452 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 48 footprint_gp_smoothv1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 436106 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 49 euclidddf_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 433940 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 50 wfd_depth_scale0.75_noddf_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 487177 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 51 short_exp_2ns_5expt_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 486346 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 52 footprint_big_sky_nouiyv1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 450705 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 53 wfd_depth_scale0.75_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 440555 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 54 wfd_depth_scale0.99_noddf_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 477591 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 55 dcr_nham3_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 428112 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 56 rolling_mod2_sdf_0.20_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 432139 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 57 bulges_bs_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 431430 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 58 twi_filters_4_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 435973 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 59 dcr_nham1_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 430488 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 60 footprint_newAv1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 436089 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 61 footprint_standard_goalsv1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 435973 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 62 bulges_bulge_wfd_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 431960 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 63 twi_filters_1_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 403913 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 64 weather_1.2_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 615438 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 65 footprint_newBv1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 435950 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 66 dcr_nham4_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 426477 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 67 weather_0.7_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 511060 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 68 short_exp_5ns_5expt_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 546476 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 69 wfd_depth_scale0.65_noddf_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 491837 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 70 footprint_stuck_rollingv1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 438523 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 71 wfd_depth_scale0.80_noddf_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 485004 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 72 pair_strategy_0_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 445233 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 73 twilight_neo_mod3_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 501853 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 74 rolling_mod3_sdf_0.20_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 432448 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# 75 weather_1.2_ndt_v1.4_10yrs
# Querying database SummaryAllProps with constraint filter = "r" and note not like "DD%" for columns ['fieldRA', 'fieldDec', 'observationStartMJD']
# Found 671412 visits
# Running:  ['logTgaps']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.

# %% [markdown]
# Once this script has finished (about 5 hours), you can make plots with `plotLogTGapsMetric.ipynb`.
